# %%
import numpy as np
import pandas as pd

# %%
# Load csv file to DataFrame
# Dataset explanation:
# https://kaggle.com/arathipraj/house-data
df = pd.read_csv('houses.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# <b>Correlation matrix - housing data</b>

# %%
# Correlations to separate DataFrame
# Default method is Pearson-correlation
correlations = df.corr(numeric_only=True)

# %%
# Show correlation matrix
# Lots of columns, hard to read
correlations
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# Highlight high 10% qauntile with style
correlations.style.highlight_quantile(axis=None, q_left=0.9, color="darkgreen")
# Out:
# <style type="text/css">
# #T_bec32_row0_col0, #T_bec32_row1_col1, #T_bec32_row1_col4, #T_bec32_row2_col2, #T_bec32_row3_col3, #T_bec32_row3_col4, #T_bec32_row3_col11, #T_bec32_row4_col1, #T_bec32_row4_col3, #T_bec32_row4_col4, #T_bec32_row4_col10, #T_bec32_row4_col11, #T_bec32_row4_col18, #T_bec32_row5_col5, #T_bec32_row5_col19, #T_bec32_row6_col6, #T_bec32_row7_col7, #T_bec32_row8_col8, #T_bec32_row9_col9, #T_bec32_row10_col4, #T_bec32_row10_col10, #T_bec32_row10_col11, #T_bec32_row10_col18, #T_bec32_row11_col3, #T_bec32_row11_col4, #T_bec32_row11_col10, #T_bec32_row11_col11, #T_bec32_row11_col18, #T_bec32_row12_col12, #T_bec32_row13_col13, #T_bec32_row14_col14, #T_bec32_row15_col15, #T_bec32_row16_col16, #T_bec32_row17_col17, #T_bec32_row18_col4, #T_bec32_row18_col10, #T_bec32_row18_col11, #T_bec32_row18_col18, #T_bec32_row19_col5, #T_bec32_row19_col19 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_bec32">
#   <thead>
#     <tr>
# ...

# %%
# Highlight low 10% qauntile with style
correlations.style.highlight_quantile(axis=None, q_right=0.1, color="darkred")
# Out:
# <style type="text/css">
# #T_f7b3e_row0_col19, #T_f7b3e_row2_col15, #T_f7b3e_row3_col15, #T_f7b3e_row4_col15, #T_f7b3e_row6_col9, #T_f7b3e_row6_col12, #T_f7b3e_row9_col6, #T_f7b3e_row9_col10, #T_f7b3e_row9_col11, #T_f7b3e_row9_col13, #T_f7b3e_row10_col9, #T_f7b3e_row10_col15, #T_f7b3e_row11_col9, #T_f7b3e_row11_col15, #T_f7b3e_row12_col6, #T_f7b3e_row12_col13, #T_f7b3e_row12_col17, #T_f7b3e_row13_col9, #T_f7b3e_row13_col12, #T_f7b3e_row13_col14, #T_f7b3e_row13_col15, #T_f7b3e_row13_col16, #T_f7b3e_row14_col13, #T_f7b3e_row15_col2, #T_f7b3e_row15_col3, #T_f7b3e_row15_col4, #T_f7b3e_row15_col10, #T_f7b3e_row15_col11, #T_f7b3e_row15_col13, #T_f7b3e_row15_col17, #T_f7b3e_row15_col18, #T_f7b3e_row15_col19, #T_f7b3e_row16_col13, #T_f7b3e_row16_col17, #T_f7b3e_row17_col12, #T_f7b3e_row17_col15, #T_f7b3e_row17_col16, #T_f7b3e_row18_col15, #T_f7b3e_row19_col0, #T_f7b3e_row19_col15 {
#   background-color: darkred;
# }
# </style>
# <table id="T_f7b3e">
#   <thead>
#     <tr>
# ...

# %%
# You can also use dtale for correlation matrix inspection
# NOTE: use original DataFrame
import dtale

# %%
# Show data frame in web browser
dtale.show(df).open_browser()

# %%
# pandasgui works also for correlation
#from pandasgui import show
#df.show()
