# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('houses.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Filter a single house with certain id
single_house = df[df['id'] == 3793500160]
single_house
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 9  3793500160  20150312T000000  323000.0         3        2.5         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 9      6560     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 9        7570
#
# [1 rows x 21 columns]

# %%
# Also iloc[] works
single_house = df.iloc[13571]
single_house.to_frame()
# Out:
#                          13571
# id                  1026069061
# date           20150129T000000
# price                 682000.0
# bedrooms                     4
# bathrooms                  2.5
# sqft_living               3600
# sqft_lot                203425
# floors                     2.0
# waterfront                   0
# view                         0
# condition                    3
# grade                        9
# sqft_above                3400
# sqft_basement              200
# yr_built                  1979
# yr_renovated                 0
# zipcode                  98077
# lat                    47.7597
# long                  -122.018
# sqft_living15             3150
# sqft_lot15              202989

# %%
max_house = df.loc[df['price'].idxmax()]
max_house.to_frame()
# Out:
#                           7252
# id                  6762700020
# date           20141013T000000
# price                7700000.0
# bedrooms                     6
# bathrooms                  8.0
# sqft_living              12050
# sqft_lot                 27600
# floors                     2.5
# waterfront                   0
# view                         3
# condition                    4
# grade                       13
# sqft_above                8570
# sqft_basement             3480
# yr_built                  1910
# yr_renovated              1987
# zipcode                  98102
# lat                    47.6298
# long                  -122.323
# sqft_living15             3940
# sqft_lot15                8800

# %% [markdown]
# <h4>Best way to do it:</h4>

# %%
# nlargest() prints
df.nlargest(5, 'price')
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# 
df.nsmallest(5, 'price')
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Average price
mean_price = df['price'].mean()
mean_price
# Out:
# 540088.1417665294

# %%
# Average bedroom size
mean_bedrooms = df['bedrooms'].mean()
mean_bedrooms
# Out:
# 3.37084162309721

# %%
# Minimum price and maximum price
min_price = df['price'].min()
max_price = df['price'].max()

# Print both values
print(min_price)
print(max_price)
# Out:
# 75000.0
# 7700000.0

# %% [markdown]
# <h4>Easiest way to do it: describe()</h4>

# %%
# override default pandas scientific notation to decimal notation 
# => easier to read
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
# All usual statistics easily
df.describe()
# Out:
#                 id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# count      21613.0   21613.0   21613.0    21613.0      21613.0   21613.0
# mean  4580301520.9  540088.1       3.4        2.1       2079.9   15107.0
# std   2876565571.3  367127.2       0.9        0.8        918.4   41420.5
# min      1000102.0   75000.0       0.0        0.0        290.0     520.0
# 25%   2123049194.0  321950.0       3.0        1.8       1427.0    5040.0
# 50%   3904930410.0  450000.0       3.0        2.2       1910.0    7618.0
# 75%   7308900445.0  645000.0       4.0        2.5       2550.0   10688.0
# max   9900000190.0 7700000.0      33.0        8.0      13540.0 1651359.0
#
#        floors  waterfront    view  condition   grade  sqft_above  \
# count 21613.0     21613.0 21613.0    21613.0 21613.0     21613.0
# mean      1.5         0.0     0.2        3.4     7.7      1788.4
# std       0.5         0.1     0.8        0.7     1.2       828.1
# ...

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# filter houses price over 2M only
houses_2M = df[df['price'] > 2000000]
houses_2M
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 153    7855801670  20150401T000000 2250000.0         4        3.2
# 246    2025069065  20140929T000000 2400000.0         4        2.5
# 269    7960900060  20150504T000000 2900000.0         4        3.2
# 282    7424700045  20150513T000000 2050000.0         5        3.0
# 300    3225069065  20140624T000000 3075000.0         4        5.0
# ...           ...              ...       ...       ...        ...
# 21310  2154970020  20140703T000000 2351960.0         4        4.2
# 21368  9533100285  20140630T000000 2065000.0         4        3.8
# 21506  2524069097  20140509T000000 2238890.0         5        6.5
# 21530  8964800330  20150407T000000 3000000.0         4        3.8
# 21576  9253900271  20150107T000000 3567000.0         5        4.5
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 153           5180     19850     2.0           0     3  ...     12
# ...

# %% [markdown]
# <h3>Group by is helpfull</h3>

# %%
# Group by grade
grade_avg = df.groupby('grade').mean(numeric_only=True)
grade_avg
# Out:
#                 id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# grade
# 1     3980300371.0  142000.0       0.0        0.0        290.0   20875.0
# 3     3847882777.7  205666.7       1.0        0.2        596.7   26953.0
# 4     4324736728.2  214381.0       1.5        0.9        660.5   22101.5
# 5     3887594134.2  248524.0       2.4        1.1        983.3   24019.9
# 6     4442552374.6  301919.6       2.7        1.2       1191.6   12647.0
# 7     4527762146.0  402590.3       3.3        1.8       1689.4   11766.4
# 8     4774398776.8  542852.8       3.5        2.3       2184.7   13510.2
# 9     4651165661.2  773513.2       3.8        2.7       2868.1   20638.5
# 10    4404625777.7 1071771.1       3.9        3.0       3520.3   28191.1
# 11    4164540550.8 1496841.7       4.2        3.5       4395.4   38372.8
# 12    3895361760.5 2191222.0       4.2        4.0       5471.6   54521.3
# 13    4125711645.1 3709615.4       4.8        5.1       7483.1   28204.8
#
# ...

# %%
# get counts by category
grade_counts = df.groupby('grade').count()
grade_counts
# Out:
#          id  date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# grade
# 1         1     1      1         1          1            1         1       1
# 3         3     3      3         3          3            3         3       3
# 4        29    29     29        29         29           29        29      29
# 5       242   242    242       242        242          242       242     242
# 6      2038  2038   2038      2038       2038         2038      2038    2038
# 7      8981  8981   8981      8981       8981         8981      8981    8981
# 8      6068  6068   6068      6068       6068         6068      6068    6068
# 9      2615  2615   2615      2615       2615         2615      2615    2615
# 10     1134  1134   1134      1134       1134         1134      1134    1134
# 11      399   399    399       399        399          399       399     399
# 12       90    90     90        90         90           90        90      90
# ...

# %%
# value_counts is usually best way to go
df['grade'].value_counts().to_frame()
# Out:
#        count
# grade
# 7       8981
# 8       6068
# 9       2615
# 6       2038
# 10      1134
# 11       399
# 5        242
# 12        90
# 4         29
# 13        13
# 3          3
# 1          1

# %%
df.head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 221900.0         3        1.0         1180
# 1  6414100192  20141209T000000 538000.0         3        2.2         2570
# 2  5631500400  20150225T000000 180000.0         2        1.0          770
# 3  2487200875  20141209T000000 604000.0         4        3.0         1960
# 4  1954400510  20150218T000000 510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Not the best way, should be in dateTime format
houses_2015 = df[df['date'].str.find('2015') >= 0]
houses_2015
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2        1.0
# 4      1954400510  20150218T000000  510000.0         3        2.0
# 7      2008000270  20150115T000000  291850.0         3        1.5
# 8      2414600126  20150415T000000  229500.0         3        1.0
# 9      3793500160  20150312T000000  323000.0         3        2.5
# ...           ...              ...       ...       ...        ...
# 21604  9834201367  20150126T000000  429000.0         3        2.0
# 21606  7936000429  20150326T000000 1007500.0         4        3.5
# 21607  2997800021  20150219T000000  475000.0         3        2.5
# 21609  6600060120  20150223T000000  400000.0         4        2.5
# 21611   291310100  20150116T000000  400000.0         3        2.5
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
# Getting unique values in column
df['yr_built'].unique()
# Out:
# array([1955, 1951, 1933, 1965, 1987, 2001, 1995, 1963, 1960, 2003, 1942,
#        1927, 1977, 1900, 1979, 1994, 1916, 1921, 1969, 1947, 1968, 1985,
#        1941, 1915, 1909, 1948, 2005, 1929, 1981, 1930, 1904, 1996, 2000,
#        1984, 2014, 1922, 1959, 1966, 1953, 1950, 2008, 1991, 1954, 1973,
#        1925, 1989, 1972, 1986, 1956, 2002, 1992, 1964, 1952, 1961, 2006,
#        1988, 1962, 1939, 1946, 1967, 1975, 1980, 1910, 1983, 1978, 1905,
#        1971, 2010, 1945, 1924, 1990, 1914, 1926, 2004, 1923, 2007, 1976,
#        1949, 1999, 1901, 1993, 1920, 1997, 1943, 1957, 1940, 1918, 1928,
#        1974, 1911, 1936, 1937, 1982, 1908, 1931, 1998, 1913, 2013, 1907,
#        1958, 2012, 1912, 2011, 1917, 1932, 1944, 1902, 2009, 1903, 1970,
#        2015, 1934, 1938, 1919, 1906, 1935], dtype=int64)

# %%
# get a number of unique options in a column
df['yr_built'].nunique()
# Out:
# 116

# %%
# Printing histogram of all data frame
df['price'].hist()
# Out:
# <Axes: >

# %%
# Testing outlier filtering
df_filter = df[df['price'] < 800000]

# %%
# Print filtered histogram
df_filter['price'].hist()
# Out:
# <Axes: >
