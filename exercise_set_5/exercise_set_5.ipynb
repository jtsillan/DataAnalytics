# %% [markdown]
# <h3><b>Introduction to Data Analytics - Exercise set 5 - data processing and management</b></h3>

# %%
# Typical imports
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# <h4><b>1. </b>Download <b>"simple.json"</b> in Moodle, and load it in pandas.</b> </h4>
# <p>
# The DataFrame should look like this:
# </p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex51.png" width="1000"/>

# %%
# Download json file
df_json = pd.read_json('simple.json')
df_json
# Out:
#      id          brand          model  year                       owned_by  \
# 0     1       Chrysler        Voyager  2001                  Wolff-Trantow
# 1     2     Volkswagen          Jetta  1995     Schuppe, Pfeffer and Klein
# 2     3        Porsche        Cayenne  2005                    Mante Group
# 3     4        Porsche            928  1994                   Wisozk Group
# 4     5  Mercedes-Benz       SL-Class  2007                Schiller-Littel
# ..  ...            ...            ...   ...                            ...
# 95   96          Dodge  Ram 1500 Club  2000             Schneider-Donnelly
# 96   97            GMC  Yukon XL 2500  2001      Powlowski, Lemke and Wiza
# 97   98      Chevrolet   Sportvan G20  1992  O'Keefe, Rogahn and Gleichner
# 98   99     Mitsubishi         3000GT  1993                    Hoppe-Kunde
# 99  100      Chevrolet    TrailBlazer  2002                 Wunsch-Friesen
#
#       acquired  price
# 0   28/12/2016  11565
# 1    20/4/2016  52431
# 2    11/6/2020  75552
# 3    17/6/2019  30331
# 4    20/7/2018  62385
# ..         ...    ...
# 95   28/9/2016  56256
# 96   19/4/2016  50163
# 97    1/6/2019   8577
# 98  29/12/2018  23180
# 99  14/11/2018  76830
#
# [100 rows x 7 columns]

# %% [markdown]
# <h4><b>2.</b> Download <b>"simple.xml"</b> in Moodle, and load it in pandas</h4>
# <p>The Series should look something like this:
# </p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex52.png" />

# %%
# Load xml from file, use xpath as first element of root node
df_xml = pd.read_xml('simple.xml', xpath="/*")
df_xml
# Out:
#    id       brand   model  year                    owned_by    acquired  price
# 0   1  Oldsmobile  Aurora  2003  Herzog, Rodriguez and Howe  21/10/2016  32571

# %% [markdown]
# <h4><b>3. Load this API-data into a pandas DataFrame:</b></h4>
# <p><a href="https://edu.frostbit.fi/api/events">https://edu.frostbit.fi/api/events</a></p>

# %% [markdown]
# <p>
# Remember to use json_normalize to help you out with the categories and address information.<br /><b>Have address information in their own columns, and categories as separate rows.</b><br />The DataFrame should look something like this (note that the data changes daily, and exact values will vary):
#
#
# </p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex53.png"/>

# %%
# Imports for exercise
import requests
import json

# %%
# Url for upload data
url = "https://edu.frostbit.fi/api/events/"
# Save data to json by url request
data = json.loads(requests.get(url).text)
data
# Out:
# [{'name': 'Viikinrannan−Lahdenväylän osayleiskaavaluonnos nähtävillä',
#   'date': '11.4.2024',
#   'categories': ['kaavoitus (maankäyttö)',
#    'kaupunkirakenne',
#    'keskustelu',
#    'osallistuminen',
#    'osallisuus',
#    'yleiskaavoitus'],
#   'address': {'street_address': 'Viikinkaari 11', 'postal_code': '00790'}},
#  {'name': 'Digitalkkari',
#   'date': '10.5.2024',
#   'categories': ['digineuvonta', 'opastus'],
#   'address': {'street_address': 'Kiviparintie 2', 'postal_code': '00920'}},
#  {'name': 'ورشة البحث عن العمل',
#   'date': '25.4.2024',
#   'categories': ['maahanmuuttajat',
#    'neuvonta',
#    'opastus',
#    'työllisyys',
#    'työnhakijat',
#    'työnhaku'],
#   'address': {'street_address': 'Asiakkaankatu 3A', 'postal_code': '00930'}},
#  {'name': 'Pukinmäen taidekoulun oppilaiden kevätnäyttely',
#   'date': '3.4.2024',
#   'categories': ['kulttuuritapahtumat'],
#   'address': {'street_address': 'Kenttäkuja 12', 'postal_code': '00720'}},
#  {'name': 'Seniorisäpinät',
#   'date': '2.5.2024',
#   'categories': [],
#   'address': {'street_address': 'Jauhokuja 3', 'postal_code': '00920'}},
#  {'name': 'Tšernobyl ja ydinvoima kulttuurintutkijan silmin',
#   'date': '15.4.2024',
#   'categories': ['näyttelyt'],
#   'address': {'street_address': 'Töölönlahdenkatu 4', 'postal_code': '00100'}},
#  {'name': 'Antti Kujala: Kuin veljet keskenään',
#   'date': '18.4.2024',
#   'categories': ['kirjallisuus', 'luennot'],
#   'address': {'street_address': 'Rikhardinkatu 3', 'postal_code': '00130'}},
#  {'name': 'Kino Maunula',
#   'date': '5.4.2024',
#   'categories': ['elokuvat', 'luennot'],
#   'address': {'street_address': 'Metsäpurontie 4', 'postal_code': '00630'}},
#  {'name': 'Salsa con Sabor',
#   'date': '7.4.2024',
#   'categories': ['musiikki', 'salsa (tanssit)', 'tanssi', 'tanssitapahtumat'],
#   'address': {'street_address': 'Sörnäisten rantatie 22 / Kaasutehtaankatu 1',
#    'postal_code': '00540'}},
#  {'name': 'Kyy lähiluonnossamme',
#   'date': '10.4.2024',
#   'categories': ['keskustelu', 'luennot', 'opastus', 'osallistuminen'],
#   'address': {'street_address': 'Ostostie 4', 'postal_code': '00940'}}]

# %%
# Lets try to normalize --> doesn't look that good
events = pd.json_normalize(data)
events
# Out:
#                                                 name       date  \
# 0  Viikinrannan−Lahdenväylän osayleiskaavaluonnos...  11.4.2024
# 1                                       Digitalkkari  10.5.2024
# 2                                ورشة البحث عن العمل  25.4.2024
# 3     Pukinmäen taidekoulun oppilaiden kevätnäyttely   3.4.2024
# 4                                     Seniorisäpinät   2.5.2024
# 5   Tšernobyl ja ydinvoima kulttuurintutkijan silmin  15.4.2024
# 6                Antti Kujala: Kuin veljet keskenään  18.4.2024
# 7                                       Kino Maunula   5.4.2024
# 8                                    Salsa con Sabor   7.4.2024
# 9                               Kyy lähiluonnossamme  10.4.2024
#
#                                           categories  \
# 0  [kaavoitus (maankäyttö), kaupunkirakenne, kesk...
# 1                            [digineuvonta, opastus]
# 2  [maahanmuuttajat, neuvonta, opastus, työllisyy...
# 3                              [kulttuuritapahtumat]
# 4                                                 []
# 5                                        [näyttelyt]
# 6                            [kirjallisuus, luennot]
# 7                                [elokuvat, luennot]
# 8  [musiikki, salsa (tanssit), tanssi, tanssitapa...
# 9     [keskustelu, luennot, opastus, osallistuminen]
#
#                         address.street_address address.postal_code
# 0                               Viikinkaari 11               00790
# 1                               Kiviparintie 2               00920
# 2                             Asiakkaankatu 3A               00930
# 3                                Kenttäkuja 12               00720
# 4                                  Jauhokuja 3               00920
# 5                           Töölönlahdenkatu 4               00100
# 6                              Rikhardinkatu 3               00130
# 7                              Metsäpurontie 4               00630
# 8  Sörnäisten rantatie 22 / Kaasutehtaankatu 1               00540
# 9                                   Ostostie 4               00940

# %%
# Let's try some other method
from flatten_json import flatten

# Flatten events data and create DataFrame
dict_flatten = (flatten(x, '.') for x in data)
events_flattened = pd.DataFrame(dict_flatten)

# %%
# Flattened data looks ok. There is lots of NaN values in different categories.
# And there is two address in one row. Let's leave it there since it was like that in original data.
events_flattened
# Out:
#                                                 name       date  \
# 0  Viikinrannan−Lahdenväylän osayleiskaavaluonnos...  11.4.2024
# 1                                       Digitalkkari  10.5.2024
# 2                                ورشة البحث عن العمل  25.4.2024
# 3     Pukinmäen taidekoulun oppilaiden kevätnäyttely   3.4.2024
# 4                                     Seniorisäpinät   2.5.2024
# 5   Tšernobyl ja ydinvoima kulttuurintutkijan silmin  15.4.2024
# 6                Antti Kujala: Kuin veljet keskenään  18.4.2024
# 7                                       Kino Maunula   5.4.2024
# 8                                    Salsa con Sabor   7.4.2024
# 9                               Kyy lähiluonnossamme  10.4.2024
#
#              categories.0     categories.1 categories.2      categories.3  \
# 0  kaavoitus (maankäyttö)  kaupunkirakenne   keskustelu    osallistuminen
# 1            digineuvonta          opastus          NaN               NaN
# 2         maahanmuuttajat         neuvonta      opastus        työllisyys
# 3     kulttuuritapahtumat              NaN          NaN               NaN
# 4                     NaN              NaN          NaN               NaN
# 5               näyttelyt              NaN          NaN               NaN
# 6            kirjallisuus          luennot          NaN               NaN
# 7                elokuvat          luennot          NaN               NaN
# 8                musiikki  salsa (tanssit)       tanssi  tanssitapahtumat
# 9              keskustelu          luennot      opastus    osallistuminen
#
#   categories.4    categories.5                       address.street_address  \
# 0   osallisuus  yleiskaavoitus                               Viikinkaari 11
# 1          NaN             NaN                               Kiviparintie 2
# 2  työnhakijat        työnhaku                             Asiakkaankatu 3A
# 3          NaN             NaN                                Kenttäkuja 12
# 4          NaN             NaN                                  Jauhokuja 3
# 5          NaN             NaN                           Töölönlahdenkatu 4
# 6          NaN             NaN                              Rikhardinkatu 3
# 7          NaN             NaN                              Metsäpurontie 4
# 8          NaN             NaN  Sörnäisten rantatie 22 / Kaasutehtaankatu 1
# 9          NaN             NaN                                   Ostostie 4
#
#   address.postal_code categories
# 0               00790        NaN
# 1               00920        NaN
# 2               00930        NaN
# 3               00720        NaN
# 4               00920         []
# 5               00100        NaN
# 6               00130        NaN
# 7               00630        NaN
# 8               00540        NaN
# 9               00940        NaN

# %%
# Let's remove old categories column
events_flattened = events_flattened.drop('categories', axis=1)
events_flattened
# Out:
#                                                 name       date  \
# 0  Viikinrannan−Lahdenväylän osayleiskaavaluonnos...  11.4.2024
# 1                                       Digitalkkari  10.5.2024
# 2                                ورشة البحث عن العمل  25.4.2024
# 3     Pukinmäen taidekoulun oppilaiden kevätnäyttely   3.4.2024
# 4                                     Seniorisäpinät   2.5.2024
# 5   Tšernobyl ja ydinvoima kulttuurintutkijan silmin  15.4.2024
# 6                Antti Kujala: Kuin veljet keskenään  18.4.2024
# 7                                       Kino Maunula   5.4.2024
# 8                                    Salsa con Sabor   7.4.2024
# 9                               Kyy lähiluonnossamme  10.4.2024
#
#              categories.0     categories.1 categories.2      categories.3  \
# 0  kaavoitus (maankäyttö)  kaupunkirakenne   keskustelu    osallistuminen
# 1            digineuvonta          opastus          NaN               NaN
# 2         maahanmuuttajat         neuvonta      opastus        työllisyys
# 3     kulttuuritapahtumat              NaN          NaN               NaN
# 4                     NaN              NaN          NaN               NaN
# 5               näyttelyt              NaN          NaN               NaN
# 6            kirjallisuus          luennot          NaN               NaN
# 7                elokuvat          luennot          NaN               NaN
# 8                musiikki  salsa (tanssit)       tanssi  tanssitapahtumat
# 9              keskustelu          luennot      opastus    osallistuminen
#
#   categories.4    categories.5                       address.street_address  \
# 0   osallisuus  yleiskaavoitus                               Viikinkaari 11
# 1          NaN             NaN                               Kiviparintie 2
# 2  työnhakijat        työnhaku                             Asiakkaankatu 3A
# 3          NaN             NaN                                Kenttäkuja 12
# 4          NaN             NaN                                  Jauhokuja 3
# 5          NaN             NaN                           Töölönlahdenkatu 4
# 6          NaN             NaN                              Rikhardinkatu 3
# 7          NaN             NaN                              Metsäpurontie 4
# 8          NaN             NaN  Sörnäisten rantatie 22 / Kaasutehtaankatu 1
# 9          NaN             NaN                                   Ostostie 4
#
#   address.postal_code
# 0               00790
# 1               00920
# 2               00930
# 3               00720
# 4               00920
# 5               00100
# 6               00130
# 7               00630
# 8               00540
# 9               00940

# %% [markdown]
# <h4><b>4. Use web scraping (e.g. BeautifulSoup), and use it to get the following info from the Rovaniemi Wikipedia –page</b></h4>
# <p><b>Wiki-page:</b> <a href="https://en.wikipedia.org/wiki/Rovaniemi">https://en.wikipedia.org/wiki/Rovaniemi</a></p>

# %% [markdown]
# <b>Tasks:</b>
# <ul>
#     <li>Get the coordinates of Rovaniemi (upper right corner)</li>
#     <li>Get the nickname of Rovaniemi (under coat of arms)</li>
# </ul>
#
# <b>Advanced extra tasks:</b>
# <ul>
#     <li><b>Get the total population</b></li>
#     <ul>
#         <li><b>Note:</b> this is a good example why webscraping can be tedious, since you'll have to traverse the HTML-tree to get what you want. This might be helpful:<br />
# <a href="https://realpython.com/beautiful-soup-web-scraper-python/">https://realpython.com/beautiful-soup-web-scraper-python/</a></li>
#     </ul>
#
# </ul>
#
# <ul>
#     <li><b>Get the total area</b></li>
#     <ul>
#         <li>Convert this number into a float decimal (i.e. remove commas and the unit and call float() –in Python!)</li>
#     </ul>
#
# </ul>

# %%
# Import Beautifulsoap
from bs4 import BeautifulSoup

# %%
# Url to get data
url = "https://en.wikipedia.org/wiki/Rovaniemi"
# Responce from get request
page = requests.get(url)
# Variable to store page content as a soap object
soap = BeautifulSoup(page.content, 'html.parser')

# %%
# Find coordinates from soup
coord = soap.find('span', id='coordinates').text
# Some parsing would be nice, but it's good enough.
coord
# Out:
# 'Coordinates: 66°30′N 025°44′E\ufeff / \ufeff66.500°N 25.733°E\ufeff / 66.500; 25.733'

# %%
# Find all elements with html element 'tr' and class 'mergedtoprow'
nicknames = soap.find_all('tr', class_='mergedtoprow')
len(nicknames)
# Out:
# 14

# %%
for col in nicknames:
    #print(col)
    if col.find('td') != None:        
        #print(col.text)
        info = col.findNext('div')
        print(col)
        print(info)
        print('----------------------------')
        print(info.text)
        print('****************************')
# Out:
# <tr class="mergedtoprow ib-settlement-official"><td class="infobox-full-data" colspan="2"><span title="Finnish-language text"><i lang="fi">Rovaniemen kaupunki</i></span><br/><span title="Swedish-language text"><i lang="sv">Rovaniemi stad</i></span><br/><span title="English-language text"><span lang="en">City of Rovaniemi</span></span></td></tr>
# <div class="ib-settlement-caption">Clockwise from top: the <a href="/wiki/Rovaniemi_Church" title="Rovaniemi Church">Rovaniemi Church</a>, the <a href="/wiki/Rovaniemi_Airport" title="Rovaniemi Airport">Rovaniemi Airport</a>, the <a href="/wiki/Santa_Claus_Village" title="Santa Claus Village">Santa Claus Village</a>, downtown Rovaniemi, a view of the city from Ounasvaara, the <a href="/wiki/Arktikum_Science_Museum" title="Arktikum Science Museum">Arktikum Science Museum</a>, and <a class="mw-redirect" href="/wiki/Aurora_borealis" title="Aurora borealis">aurora borealis</a> in Someroharju.</div>
# ----------------------------
# Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju.
# ****************************
# <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi_Montage.jpg" title="Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju."><img alt="Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju." class="mw-file-element" data-file-height="2832" data-file-width="1750" decoding="async" height="405" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/250px-Rovaniemi_Montage.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/375px-Rovaniemi_Montage.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/500px-Rovaniemi_Montage.jpg 2x" width="250"/></a></span><div class="ib-settlement-caption">Clockwise from top: the <a href="/wiki/Rovaniemi_Church" title="Rovaniemi Church">Rovaniemi Church</a>, the <a href="/wiki/Rovaniemi_Airport" title="Rovaniemi Airport">Rovaniemi Airport</a>, the <a href="/wiki/Santa_Claus_Village" title="Santa Claus Village">Santa Claus Village</a>, downtown Rovaniemi, a view of the city from Ounasvaara, the <a href="/wiki/Arktikum_Science_Museum" title="Arktikum Science Museum">Arktikum Science Museum</a>, and <a class="mw-redirect" href="/wiki/Aurora_borealis" title="Aurora borealis">aurora borealis</a> in Someroharju.</div></td></tr>
# <div class="ib-settlement-caption">Clockwise from top: the <a href="/wiki/Rovaniemi_Church" title="Rovaniemi Church">Rovaniemi Church</a>, the <a href="/wiki/Rovaniemi_Airport" title="Rovaniemi Airport">Rovaniemi Airport</a>, the <a href="/wiki/Santa_Claus_Village" title="Santa Claus Village">Santa Claus Village</a>, downtown Rovaniemi, a view of the city from Ounasvaara, the <a href="/wiki/Arktikum_Science_Museum" title="Arktikum Science Museum">Arktikum Science Museum</a>, and <a class="mw-redirect" href="/wiki/Aurora_borealis" title="Aurora borealis">aurora borealis</a> in Someroharju.</div>
# ----------------------------
# Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju.
# ****************************
# <tr class="mergedtoprow"><td class="infobox-full-data maptable" colspan="2"><style data-mw-deduplicate="TemplateStyles:r1028600610">.mw-parser-output .ib-settlement-cols{text-align:center;display:table;width:100%}.mw-parser-output .ib-settlement-cols-row{display:table-row}.mw-parser-output .ib-settlement-cols-cell{display:table-cell;vertical-align:middle}.mw-parser-output .ib-settlement-cols-cellt{display:table-cell;vertical-align:top}</style>
# <div class="ib-settlement-cols">
# <div class="ib-settlement-cols-row"><div class="ib-settlement-cols-cell"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.lippu.svg" title="Flag of Rovaniemi"><img alt="Flag of Rovaniemi" class="mw-file-element" data-file-height="800" data-file-width="1200" decoding="async" height="70" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/105px-Rovaniemi.lippu.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/158px-Rovaniemi.lippu.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/210px-Rovaniemi.lippu.svg.png 2x" width="105"/></a></span><div class="ib-settlement-caption-link">Flag</div></div><div class="ib-settlement-cols-cell"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.vaakuna.svg" title="Coat of arms of Rovaniemi"><img alt="Coat of arms of Rovaniemi" class="mw-file-element" data-file-height="568" data-file-width="500" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/70px-Rovaniemi.vaakuna.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/106px-Rovaniemi.vaakuna.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/141px-Rovaniemi.vaakuna.svg.png 2x" width="70"/></a></span><div class="ib-settlement-caption-link">Coat of arms</div></div></div></div></td></tr>
# <div class="ib-settlement-cols">
# <div class="ib-settlement-cols-row"><div class="ib-settlement-cols-cell"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.lippu.svg" title="Flag of Rovaniemi"><img alt="Flag of Rovaniemi" class="mw-file-element" data-file-height="800" data-file-width="1200" decoding="async" height="70" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/105px-Rovaniemi.lippu.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/158px-Rovaniemi.lippu.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/210px-Rovaniemi.lippu.svg.png 2x" width="105"/></a></span><div class="ib-settlement-caption-link">Flag</div></div><div class="ib-settlement-cols-cell"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.vaakuna.svg" title="Coat of arms of Rovaniemi"><img alt="Coat of arms of Rovaniemi" class="mw-file-element" data-file-height="568" data-file-width="500" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/70px-Rovaniemi.vaakuna.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/106px-Rovaniemi.vaakuna.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/141px-Rovaniemi.vaakuna.svg.png 2x" width="70"/></a></span><div class="ib-settlement-caption-link">Coat of arms</div></div></div></div>
# ----------------------------
#
# FlagCoat of arms
# ****************************
# <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2">Nickname(s): <div class="ib-settlement-nickname nickname">Arctic Capital; Hometown of <a href="/wiki/Santa_Claus" title="Santa Claus">Santa Claus</a></div></td></tr>
# <div class="ib-settlement-nickname nickname">Arctic Capital; Hometown of <a href="/wiki/Santa_Claus" title="Santa Claus">Santa Claus</a></div>
# ----------------------------
# Arctic Capital; Hometown of Santa Claus
# ****************************
# <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi_sijainti_Suomi.svg" title="Location of Rovaniemi in Finland"><img alt="Location of Rovaniemi in Finland" class="mw-file-element" data-file-height="2950" data-file-width="1750" decoding="async" height="421" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/250px-Rovaniemi_sijainti_Suomi.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/375px-Rovaniemi_sijainti_Suomi.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/500px-Rovaniemi_sijainti_Suomi.svg.png 2x" width="250"/></a></span><div class="ib-settlement-caption">Location of Rovaniemi in Finland</div></td></tr>
# <div class="ib-settlement-caption">Location of Rovaniemi in Finland</div>
# ----------------------------
# Location of Rovaniemi in Finland
# ****************************
# <tr class="mergedtoprow"><th class="infobox-label" scope="row"><a href="/wiki/Time_zone" title="Time zone">Time zone</a></th><td class="infobox-data"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">UTC+02:00</a> (<a href="/wiki/Eastern_European_Time" title="Eastern European Time">EET</a>)</td></tr>
# <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/Battle_of_Rovaniemi" title="Battle of Rovaniemi">Battle of Rovaniemi</a></div>
# ----------------------------
# Main article: Battle of Rovaniemi
# ****************************
# <tr class="mergedtoprow"><th class="infobox-label" scope="row">Website</th><td class="infobox-data"><a class="external text" href="https://international.rovaniemi.fi/en" rel="nofollow">www.rovaniemi.fi</a></td></tr>
# <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/Battle_of_Rovaniemi" title="Battle of Rovaniemi">Battle of Rovaniemi</a></div>
# ----------------------------
# Main article: Battle of Rovaniemi
# ****************************

# %% [markdown]
# <h4><b>5. Use web scraping, and create a DataFrame of this table: </b></h4>
# <p> <a href="https://en.wikipedia.org/wiki/List_of_countries_by_average_yearly_temperature">https://en.wikipedia.org/wiki/List_of_countries_by_average_yearly_temperature</a></p>

# %% [markdown]
# <ul>
#     <li>Change the name of the value column to "avg_temp" as well (pandas column rename)</li>
# </ul>
#
# <b>Advanced extra task:</b>
# <ul>
#     <li><b>Scrape these two tables as well</b></li>
#     <ul>
#         <li><a href="https://en.wikipedia.org/wiki/List_of_countries_by_employment_rate">https://en.wikipedia.org/wiki/List_of_countries_by_employment_rate</a></li>
#         <li><a href="https://en.wikipedia.org/wiki/List_of_countries_by_unemployment_rate">https://en.wikipedia.org/wiki/List_of_countries_by_unemployment_rate</a></li>
#     </ul>
#     <br />
#     <ul>
#         <li><b>Combine the tables into a single DataFrame so that you get only the data of year 2020 or newer, and have the columns <span style="color: darkorange">"Country", "EmploymentRate"</span> and <span style="color: darkorange">"UnemploymentRate"</span>. You can also create additional columns <span style="color: red">"EmploymentRate15_24"</span>and <span style="color: red">" EmploymentRate25_70"</span> if you scrape the OECD-table as well! </b>
#
# </li>
#     </ul>
# </ul>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex55stocks.jpg" width="450" />

# %% [markdown]
# <h4><b>6. Simple merging:</b> Download <u><b>coffee_sales.csv</b></u> and <b><u>temperatures_fixed.csv</u></b> from Moodle.<b></h4>
# <p>Use merging to combine these files into one DataFrame, containing the coffee sales data and the corresponding temperature –data. (merge(), see materials for examples)</p>

# %% [markdown]
# <span style="color: red;"><b>Use left join, and coffee sales as the first DataFrame!</b></span>

# %%
# code here

# %% [markdown]
# <b>Extra task: </b> Do the same but with <b>temperatures_unfixed.csv</b> instead. Remember <b>groupby()</b> before attempting merging!
#
# <b>Also, you might want to remove some of the columns before grouping data => <span style="color: red;">Summary + Hour</span>. </b>
#
# <span><i>You can also try to merge the DataFrames so that the Summary –of the weather is also added. For this, you probably need to figure out first how to determine the "average" Summary for each day (extra challenge!).</i></span>

# %%
# extra task code here, if done

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex56coffee.jpg" width="450" />

# %% [markdown]
# <h2><b>Advanced extra tasks for extra points (varying challenges, some require Googling):</b></h2>

# %% [markdown]
# <ul>
# <li><b>1. Download the "complex.json" –file from Moodle.</b> Note that this data is fairly complex (i.e. heavily nested). Use json_normalize and other needed methods to convert this data into a workable DataFrame.</li>
# </ul>

# %%
# code for the advanced extra task

# %% [markdown]
# <ul>
# <li><b>2. Load the "simple.json" –file without pandas, and try to get the average price with plain Python. </li>
# </ul>

# %%
# code for the advanced extra task

# %% [markdown]
# <ul>
# <li><b>3. Download the "complex.xml" file from Moodle, and create a DataFrame out of it.</b></li>
# <ul>
#     <li><b>Note:</b> using pandas.read_xml() would otherwise work, but it ignores the "ownership" –field. You'll have to find another way to get this data into your DataFrame as well!</li>
# </ul>
# </ul>

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

# %% [markdown]
# <ul>
#     <li><b>4. Try out Selenium on a site that cannot be scraped with traditional methods. You can use this tutorial as the starting point:</b></li>
#     <ul>
#         <li><a href="https://www.toptal.com/python/web-scraping-with-python">https://www.toptal.com/python/web-scraping-with-python</a></li>
#     </ul>
# </ul>

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_5/ex5charts.jpg" width="600" />

# %% [markdown]
# <b>5. Extra challenging advanced task: <span style="color: red;">integrating data sources</span></b>

# %% [markdown]
# <ul>
# <li><b>Integrate two or more datasets into one matching dataset  (pandas DataFrame), but use any datasets you can find in Kaggle instead of the previous coffee sales + temperature -datasets</b></li>
# <br />
# <ul>
# <li>Find two or more datasets (Kaggle etc.) that have something in common and can be used for merging. </li>
# </ul>
#
# <br />
# <ul>
# <li><b>Typical common columns:</b></li>
# <ul>
# <li>Coordinates (lat/lng etc.)</li>
# <li>Years, months</li>
# <li>reference ids (e.g. product id -> product data)</li>
# </ul>
# </ul>
#
# <br />
# <ul>
# <li><b>You can use pandas.merge() in order to combine DataFrames</b></li>
# <ul>
# <li>When combining DataFrames, make sure that the merge doesn’t mess up your data</li>
# <li><b>Note:</b> merge can often create way too many extra rows depending on the merging parameters</li>
#
# </ul>
# </ul>
#
# <br />
# <ul>
# <li><b>This exercise can provide even large amounts of points, depending on difficulty. Aspects that affect grading:</b></li>
# <ul>
# <li>Amount of datasets</li>
# <li>Difficulty of the datasets</li>
# <li>Using different data formats all at once (XML, JSON, CSV etc.)</li>
# <li>Other techniques used to add data: web scraping, data APIs etc.</li>
# </ul>
# </ul>
#
#
# </ul>

# %%
# this exercise is probably better to do in a separate Jupyter notebook
